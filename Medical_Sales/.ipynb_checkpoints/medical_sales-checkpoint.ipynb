# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns

# %%
file_path = "/Users/arjun/Downloads/Pharmacy_OLTP_SLStyle_18Months.csv"
sales = pd.read_csv(file_path)
sales.head()
print("Total rows:", len(sales))
# Out:
# Total rows: 50000

# %%
print(sales.columns.tolist())  # List of all column names
print("\nNumber of columns:", len(sales.columns))
num_cols = len(sales.columns)
# Out:
# ['Transaction_ID', 'Transaction_Date', 'Branch_ID', 'Branch_Name', 'District', 'Province', 'Payment_Method', 'Customer_Gender', 'Customer_Age', 'Customer_City', 'Medicine_ID', 'Medicine_Name', 'Generic_Name', 'Medicine_Category', 'Dosage_Form', 'Strength_mg', 'Pack_Size', 'Supplier_Name', 'Prescription_Required', 'Batch_No', 'Expiry_Date', 'Quantity', 'Unit_Price_LKR', 'Discount_Rate', 'Line_Total_LKR', 'Year', 'Month']
#
# Number of columns: 27

# %% [markdown]
# **EDA**

# %%
#null value check
print(sales.isnull().sum()) #results shows Strength_mg has 31236 null values

print((sales.isnull().sum() / len(sales) * 100).round(2))
#62.47 % null values in that one colomn only
# Out:
# Transaction_ID               0
# Transaction_Date             0
# Branch_ID                    0
# Branch_Name                  0
# District                     0
# Province                     0
# Payment_Method               0
# Customer_Gender              0
# Customer_Age                 0
# Customer_City                0
# Medicine_ID                  0
# Medicine_Name                0
# Generic_Name                 0
# Medicine_Category            0
# Dosage_Form                  0
# Strength_mg              31236
# Pack_Size                    0
# Supplier_Name                0
# Prescription_Required        0
# Batch_No                     0
# Expiry_Date                  0
# Quantity                     0
# Unit_Price_LKR               0
# Discount_Rate                0
# Line_Total_LKR               0
# Year                         0
# Month                        0
# dtype: int64
# Transaction_ID            0.00
# Transaction_Date          0.00
# Branch_ID                 0.00
# Branch_Name               0.00
# District                  0.00
# Province                  0.00
# Payment_Method            0.00
# Customer_Gender           0.00
# Customer_Age              0.00
# Customer_City             0.00
# Medicine_ID               0.00
# Medicine_Name             0.00
# Generic_Name              0.00
# Medicine_Category         0.00
# Dosage_Form               0.00
# Strength_mg              62.47
# Pack_Size                 0.00
# Supplier_Name             0.00
# Prescription_Required     0.00
# Batch_No                  0.00
# Expiry_Date               0.00
# Quantity                  0.00
# Unit_Price_LKR            0.00
# Discount_Rate             0.00
# Line_Total_LKR            0.00
# Year                      0.00
# Month                     0.00
# dtype: float64

# %%
#duplicate check
print("Duplicate rows:", sales.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
print(sales.describe())
# Out:
#        Transaction_ID            Transaction_Date     Branch_ID  Customer_Age  \
# count    50000.000000                       50000  50000.000000  50000.000000
# mean     25000.500000  2022-09-30 02:25:10.848000      4.001940     48.915940
# min          1.000000         2022-01-01 00:00:00      1.000000     18.000000
# 25%      12500.750000         2022-05-17 00:00:00      2.000000     33.000000
# 50%      25000.500000         2022-09-30 00:00:00      4.000000     49.000000
# 75%      37500.250000         2023-02-13 00:00:00      6.000000     65.000000
# max      50000.000000         2023-06-30 00:00:00      7.000000     80.000000
# std      14433.901067                         NaN      2.004319     18.159583
#
#         Medicine_ID   Strength_mg     Pack_Size      Quantity  Unit_Price_LKR  \
# count  50000.000000  18764.000000  50000.000000  50000.000000    50000.000000
# mean      74.543920    350.273129     35.769760      3.000780     1878.785603
# min        1.000000     50.000000     10.000000      1.000000       26.240000
# 25%       37.000000    100.000000     20.000000      2.000000     1031.060000
# 50%       74.000000    250.000000     28.000000      3.000000     1855.200000
# 75%      112.000000    500.000000     60.000000      4.000000     2755.572500
# max      148.000000   1000.000000    100.000000      5.000000     4499.410000
# std       42.797969    308.811764     28.103262      1.412112     1016.935615
#
#        Discount_Rate  Line_Total_LKR          Year        Month
# count   50000.000000    50000.000000  50000.000000  50000.00000
# mean        0.074981     5205.639957   2022.331260      5.51626
# min         0.000000       29.340000   2022.000000      1.00000
# 25%         0.040000     2106.485000   2022.000000      3.00000
# 50%         0.070000     4154.685000   2022.000000      5.00000
# 75%         0.110000     7568.817500   2023.000000      8.00000
# max         0.150000    21933.450000   2023.000000     12.00000
# std         0.043655     3960.828905      0.470671      3.30629

# %%
print(sales[sales['Strength_mg'].isnull()]['Dosage_Form'].value_counts())
# Out:
# Dosage_Form
# Cream       7982
# Sachet      6320
# Inhaler     5814
# Ointment    5741
# Syrup       5379
# Name: count, dtype: int64

# %%
print(sales[sales['Strength_mg'].notnull()]['Dosage_Form'].value_counts())
# Out:
# Dosage_Form
# Capsule    8103
# Tablet     5616
# Drops      5045
# Name: count, dtype: int64

# %%
#Strength_mg is not really needed to answer our business question, so i am dropping it for more clean dataset
sales.drop(columns=['Strength_mg'], inplace=True)
print(sales.dtypes)
# Out:
# Transaction_ID                    int64
# Transaction_Date         datetime64[ns]
# Branch_ID                         int64
# Branch_Name                      object
# District                         object
# Province                         object
# Payment_Method                   object
# Customer_Gender                  object
# Customer_Age                      int64
# Customer_City                    object
# Medicine_ID                       int64
# Medicine_Name                    object
# Generic_Name                     object
# Medicine_Category                object
# Dosage_Form                      object
# Pack_Size                         int64
# Supplier_Name                    object
# Prescription_Required            object
# Batch_No                         object
# Expiry_Date                      object
# Quantity                          int64
# Unit_Price_LKR                  float64
# Discount_Rate                   float64
# Line_Total_LKR                  float64
# Year                              int64
# Month                             int64
# dtype: object

# %%
#check for unique values in categorical colomns

cat_cols = ["Branch_Name", "Medicine_Category", "Payment_Method","Customer_Gender", "Prescription_Required",
            "Supplier_Name", "Dosage_Form", "Province"]
for col in cat_cols:
    print(f"\n{col} ({sales[col].nunique()} unique):")
    print(sales[col].value_counts())
# Out:
# Branch_Name (7 unique):
# Branch_Name
# Pharmacy - Colombo Fort    7247
# Pharmacy - Kurunegala      7236
# Pharmacy - Ratnapura       7201
# Pharmacy - Jaffna          7160
# Pharmacy - Galle           7104
# Pharmacy - Negombo         7041
# Pharmacy - Kandy City      7011
# Name: count, dtype: int64
#
# Medicine_Category (15 unique):
# Medicine_Category
# Antibiotic      7632
# Cardiac         6499
# Painkiller      5008
# Vitamin         4873
# Cough & Cold    4088
# Gastro          3436
# Diabetes        3377
# Dermatology     3363
# First Aid       2707
# Hormonal        2363
# Allergy         2034
# Antiviral       1627
# Respiratory     1301
# Antifungal      1047
# Wellness         645
# Name: count, dtype: int64
#
# Payment_Method (3 unique):
# Payment_Method
# Cash         22652
# Card         19886
# Insurance     7462
# Name: count, dtype: int64
#
# Customer_Gender (2 unique):
# Customer_Gender
# Female    25877
# Male      24123
# Name: count, dtype: int64
#
# Prescription_Required (2 unique):
# Prescription_Required
# No     27455
# Yes    22545
# Name: count, dtype: int64
#
# Supplier_Name (8 unique):
# Supplier_Name
# Ceyoka Healthcare Supply         7701
# Union Chemists Supply            7415
# Astron Pharma Supply             7195
# Softlogic Pharma Distribution    7130
# Hemas Pharma Wholesale           6184
# Ceylon Pharma Traders            5647
# Healthguard Central Supply       5459
# SPC Distribution (LK)            3269
# Name: count, dtype: int64
#
# Dosage_Form (8 unique):
# Dosage_Form
# Capsule     8103
# Cream       7982
# Sachet      6320
# Inhaler     5814
# Ointment    5741
# Tablet      5616
# Syrup       5379
# Drops       5045
# Name: count, dtype: int64
#
# Province (6 unique):
# Province
# Western          14288
# North Western     7236
# Sabaragamuwa      7201
# Northern          7160
# Southern          7104
# Central           7011
# Name: count, dtype: int64

# %%
#numerical colomn range check
num_cols = ["Customer_Age", "Quantity", "Unit_Price_LKR","Discount_Rate", "Line_Total_LKR"]
for col in num_cols:
    print(f"{col}: min={sales[col].min()}, max={sales[col].max()}, mean={sales[col].mean():.2f}")
# Out:
# Customer_Age: min=18, max=80, mean=48.92
# Quantity: min=1, max=5, mean=3.00
# Unit_Price_LKR: min=26.24, max=4499.41, mean=1878.79
# Discount_Rate: min=0.0, max=0.15, mean=0.07
# Line_Total_LKR: min=29.34, max=21933.45, mean=5205.64

# %% [markdown]
# **EDA plots**

# %%
#numerical colomns 


fig, axes = plt.subplots(2, 3, figsize=(14, 8))
axes = axes.flatten()

for i, col in enumerate(num_cols):
    axes[i].hist(sales[col].dropna(), bins=30, color="red",
                 edgecolor="white", alpha=0.8)
    axes[i].set_title(f"Distribution of {col}")
    axes[i].set_xlabel(col)
    axes[i].set_ylabel("Frequency")

axes[5].set_visible(False)

plt.suptitle("Numeric Column Distributions", fontsize=14, y=1.01)
plt.tight_layout()
plt.show()

# %%
#cateforical colomns EDA
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
axes = axes.flatten()

for i, col in enumerate(["Medicine_Category", "Payment_Method","Branch_Name", "Dosage_Form"]):
    counts = sales[col].value_counts()
    axes[i].barh(counts.index, counts.values, color="steelblue", alpha=0.8)
    axes[i].set_title(f"{col} Distribution")
    axes[i].set_xlabel("Count")

plt.suptitle("Categorical Column Distributions", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# **correlation check**

# %%
plt.figure(figsize=(10, 6))
correlation = sales[num_cols].corr()
sns.heatmap(correlation, annot=True, fmt=".2f", cmap="coolwarm",linewidths=0.5, square=True)
plt.title("Correlation Heatmap - Numeric Columns")
plt.tight_layout()
plt.show()

# %%
#colomn addition for better usage of data
sales["Expiry_Date"] = pd.to_datetime(sales["Expiry_Date"], errors="coerce") #format change
sales["Day_of_Week"] = sales["Transaction_Date"].dt.day_name() #new colomn addition
sales["Quarter"] = "Q" + sales["Transaction_Date"].dt.quarter.astype(str) 
sales["Month_Name"] = sales["Transaction_Date"].dt.strftime("%b")
sales["Days_to_Expiry"] = (sales["Expiry_Date"] - sales["Transaction_Date"]).dt.days

bins   = [0,  30,  45,  60,  100]
labels = ["Young (18-30)", "Middle (31-45)", "Senior (46-60)", "Elderly (61+)"]
sales["Age_Group"] = pd.cut(sales["Customer_Age"], bins=bins,labels=labels, right=True)

sales["Branch_Short"] = sales["Branch_Name"].str.replace("Pharmacy - ", "",regex=False)

# %%
#Revenue check

sales["Revenue_Check"] = (sales["Quantity"] * sales["Unit_Price_LKR"] * (1 - sales["Discount_Rate"])).round(2)
mismatch = (sales["Revenue_Check"] - sales["Line_Total_LKR"]).abs() > 0.05
print(f"Revenue verification: {mismatch.sum()} mismatched rows")
sales.drop(columns=["Revenue_Check"], inplace=True)
# Out:
# Revenue verification: 0 mismatched rows

# %%
#Finalnull check after data cleaning
print(sales.isnull().sum())
# Out:
# Transaction_ID           0
# Transaction_Date         0
# Branch_ID                0
# Branch_Name              0
# District                 0
# Province                 0
# Payment_Method           0
# Customer_Gender          0
# Customer_Age             0
# Customer_City            0
# Medicine_ID              0
# Medicine_Name            0
# Generic_Name             0
# Medicine_Category        0
# Dosage_Form              0
# Pack_Size                0
# Supplier_Name            0
# Prescription_Required    0
# Batch_No                 0
# Expiry_Date              0
# Quantity                 0
# Unit_Price_LKR           0
# Discount_Rate            0
# Line_Total_LKR           0
# Year                     0
# Month                    0
# Day_of_Week              0
# Quarter                  0
# Month_Name               0
# Days_to_Expiry           0
# Age_Group                0
# Branch_Short             0
# dtype: int64

# %%
fig, axes = plt.subplots(2, 3, figsize=(16, 10))
fig.suptitle("Feature Engineering — Distribution Checks", fontsize=14)

# Day of week distribution
day_order = ["Monday", "Tuesday", "Wednesday","Thursday", "Friday", "Saturday", "Sunday"]
day_counts = sales["Day_of_Week"].value_counts().reindex(day_order)
axes[0,0].bar(day_counts.index, day_counts.values,color="steelblue", edgecolor="white", alpha=0.85)
axes[0,0].set_title("Transactions by Day of Week")
axes[0,0].set_xlabel("Day")
axes[0,0].set_ylabel("Count")
axes[0,0].tick_params(axis="x", rotation=45)

# Quarter distribution
q_counts = sales["Quarter"].value_counts().sort_index()
axes[0,1].bar(q_counts.index, q_counts.values,color="tomato", edgecolor="white", alpha=0.85)
axes[0,1].set_title("Transactions by Quarter")
axes[0,1].set_xlabel("Quarter")
axes[0,1].set_ylabel("Count")

# Age group distribution
age_counts = sales["Age_Group"].value_counts()
axes[0,2].bar(age_counts.index.astype(str), age_counts.values,color="seagreen", edgecolor="white", alpha=0.85)
axes[0,2].set_title("Customer Age Group Distribution")
axes[0,2].set_xlabel("Age Group")
axes[0,2].set_ylabel("Count")
axes[0,2].tick_params(axis="x", rotation=20)

# Days to expiry distribution
axes[1,0].hist(sales["Days_to_Expiry"].dropna(), bins=40,color="mediumpurple", edgecolor="white", alpha=0.85)
axes[1,0].axvline(0, color="red", linestyle="--",linewidth=1.5, label="Today (ref)")
axes[1,0].axvline(90, color="orange", linestyle="--",linewidth=1.5, label="90 days")
axes[1,0].set_title("Days to Expiry Distribution")
axes[1,0].set_xlabel("Days to Expiry")
axes[1,0].set_ylabel("Count")
axes[1,0].legend(fontsize=8)

# Total Revenue distribution
axes[1,1].hist(sales["Line_Total_LKR"], bins=50,color="darkorange", edgecolor="white", alpha=0.85)
axes[1,1].set_title("Line Total Revenue Distribution")
axes[1,1].set_xlabel("Line Total (LKR)")
axes[1,1].set_ylabel("Count")

# transaction count by branch
b_counts = sales["Branch_Short"].value_counts()
axes[1,2].barh(b_counts.index, b_counts.values,color="steelblue", edgecolor="white", alpha=0.85)
axes[1,2].set_title("Transactions by Branch")
axes[1,2].set_xlabel("Count")

plt.tight_layout()
plt.savefig("eda_stage3_features.png", dpi=150, bbox_inches="tight")
plt.show()

# %%
sales.to_csv("pharmacy_cleaned.csv", index=False)
#from here ownwards i am going to proceed with cleaned data
sales_cleaned = pd.read_csv("pharmacy_cleaned.csv") #so this will be used in tableau for creating dashboards

# %% [markdown]
# **Time Series Revenue Trend**

# %%
sales_cleaned["Transaction_Date"] = pd.to_datetime(sales_cleaned["Transaction_Date"])

#grouping transaction date based on month
monthly = sales_cleaned.groupby(sales_cleaned["Transaction_Date"].dt.to_period("M"))["Line_Total_LKR"].sum()
monthly.index = monthly.index.to_timestamp()

# %%
rolling_avg = monthly.rolling(window=3, center=True).mean() #rolling average calculation for 3 consecutive month together, center : plotted at middle
fig, ax = plt.subplots(figsize=(12, 5))
ax.plot(monthly.index, monthly.values / 1e6, color="blue", linewidth=2, label="Monthly Revenue")
ax.plot(monthly.index, rolling_avg.values / 1e6,color="red", linewidth=2, linestyle="--", label="3-Month Rolling Avg")
ax.fill_between(monthly.index, monthly.values / 1e6, alpha=0.1, color="steelblue")
plt.xticks(rotation=45, ha="right")
ax.xaxis.set_major_formatter(mdates.DateFormatter("%b %Y"))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=2))
ax.set_title("Monthly Revenue Trend (Jan 2022 - Jun 2023)", fontsize=14)
ax.set_xlabel("Month")
ax.set_ylabel("Revenue (Million LKR)")
ax.legend()
ax.grid(axis="y", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# %%
import folium

branch_coords = {
    "Colombo Fort": (6.9355, 79.8507),
    "Negombo":      (7.2081, 79.8358),
    "Kandy City":   (7.2906, 80.6337),
    "Galle":        (6.0535, 80.2210),
    "Jaffna":       (9.6615, 80.0255),
    "Kurunegala":   (7.4818, 80.3609),
    "Ratnapura":    (6.6828, 80.3992),
}
m = folium.Map(location=[7.8731, 80.7718], zoom_start=7)
for branch, (lat, lon) in branch_coords.items():
    folium.Marker(
        location=[lat, lon],
        popup=branch,
        tooltip=branch
    ).add_to(m)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ffadead8f95831ea4071dde9978e58e0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ffadead8f95831ea4071dde9978e58e0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ffadead8f95831ea4071dde9978e58e0 = L.map(
#                 &quot;map_ffadead8f95831ea4071dde9978e58e0&quot;,
#                 {
#                     center: [7.8731, 80.7718],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e020b4d4fda56298b82d9deb38162bcc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e020b4d4fda56298b82d9deb38162bcc.addTo(map_ffadead8f95831ea4071dde9978e58e0);
#
#
#             var marker_035ae9e859fc8f4adf0fa627f26903b2 = L.marker(
#                 [6.9355, 79.8507],
#                 {
# }
#             ).addTo(map_ffadead8f95831ea4071dde9978e58e0);
#
#
#         var popup_b9352b1b3049e6b06e0a6cc7fdd96368 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2aa6adde344654ccd233798a1bd1d3b = $(`&lt;div id=&quot;html_f2aa6adde344654ccd233798a1bd1d3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Colombo Fort&lt;/div&gt;`)[0];
#                 popup_b9352b1b3049e6b06e0a6cc7fdd96368.setContent(html_f2aa6adde344654ccd233798a1bd1d3b);
#
#
#
#         marker_035ae9e859fc8f4adf0fa627f26903b2.bindPopup(popup_b9352b1b3049e6b06e0a6cc7fdd96368)
#         ;
#
#
#
#
#             marker_035ae9e859fc8f4adf0fa627f26903b2.bindTooltip(
#                 `&lt;div&gt;
#                      Colombo Fort
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_f08420f34cadebc5df112efdf4f037be = L.marker(
#                 [7.2081, 79.8358],
#                 {
# }
#             ).addTo(map_ffadead8f95831ea4071dde9978e58e0);
#
#
#         var popup_5d1fe0cb06f23263fd9186904f3d6803 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f057ab31bf36046676152099e39944e = $(`&lt;div id=&quot;html_0f057ab31bf36046676152099e39944e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Negombo&lt;/div&gt;`)[0];
#                 popup_5d1fe0cb06f23263fd9186904f3d6803.setContent(html_0f057ab31bf36046676152099e39944e);
#
#
#
#         marker_f08420f34cadebc5df112efdf4f037be.bindPopup(popup_5d1fe0cb06f23263fd9186904f3d6803)
#         ;
#
#
#
#
#             marker_f08420f34cadebc5df112efdf4f037be.bindTooltip(
#                 `&lt;div&gt;
#                      Negombo
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_453858541b2893304c7d38d5aec37f0e = L.marker(
#                 [7.2906, 80.6337],
#                 {
# }
#             ).addTo(map_ffadead8f95831ea4071dde9978e58e0);
#
#
#         var popup_7a3cee3fde3305c74407e16f9d66db65 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_35b8a68845a0f8c7b085f5a42b92b446 = $(`&lt;div id=&quot;html_35b8a68845a0f8c7b085f5a42b92b446&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kandy City&lt;/div&gt;`)[0];
#                 popup_7a3cee3fde3305c74407e16f9d66db65.setContent(html_35b8a68845a0f8c7b085f5a42b92b446);
#
#
#
#         marker_453858541b2893304c7d38d5aec37f0e.bindPopup(popup_7a3cee3fde3305c74407e16f9d66db65)
#         ;
#
#
#
#
#             marker_453858541b2893304c7d38d5aec37f0e.bindTooltip(
#                 `&lt;div&gt;
#                      Kandy City
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_1feeb6f530bc9bbc0caad4625b35eb26 = L.marker(
#                 [6.0535, 80.221],
#                 {
# }
#             ).addTo(map_ffadead8f95831ea4071dde9978e58e0);
#
#
#         var popup_e88e78900b47758c1af971413fd8e955 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_357e65f1fed513967397c7df591cf03d = $(`&lt;div id=&quot;html_357e65f1fed513967397c7df591cf03d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Galle&lt;/div&gt;`)[0];
#                 popup_e88e78900b47758c1af971413fd8e955.setContent(html_357e65f1fed513967397c7df591cf03d);
#
#
#
#         marker_1feeb6f530bc9bbc0caad4625b35eb26.bindPopup(popup_e88e78900b47758c1af971413fd8e955)
#         ;
#
#
#
#
#             marker_1feeb6f5

# %%
#calculation for revenue per branch
sales_cleaned["Branch_Short"] = sales_cleaned["Branch_Name"].str.replace("Pharmacy - ", "", regex=False)
branch_revenue = sales_cleaned.groupby("Branch_Short")["Line_Total_LKR"].sum()
branch_txns    = sales_cleaned.groupby("Branch_Short")["Transaction_ID"].count()

#transaction made per customer per city
city_stats = sales_cleaned.groupby("Customer_City").agg(
    Revenue=("Line_Total_LKR", "sum"),
    Transactions=("Transaction_ID", "count")
).reset_index()

# Coordinates – i found out using 
branch_coords = {
    "Colombo Fort": (6.9355, 79.8507),
    "Negombo":      (7.2081, 79.8358),
    "Kandy City":   (7.2906, 80.6337),
    "Galle":        (6.0535, 80.2210),
    "Jaffna":       (9.6615, 80.0255),
    "Kurunegala":   (7.4818, 80.3609),
    "Ratnapura":    (6.6828, 80.3992),
}

city_coords = {
    "Colombo":    (6.9271, 79.8612),
    "Kandy":      (7.2906, 80.6337),
    "Galle":      (6.0535, 80.2210),
    "Jaffna":     (9.6615, 80.0255),
    "Kurunegala": (7.4818, 80.3609),
    "Matara":     (5.9549, 80.5550),
    "Negombo":    (7.2081, 79.8358),
    "Ratnapura":  (6.6828, 80.3992),
}

m = folium.Map(location=[7.8731, 80.7718], zoom_start=7) #default folium setting

# %%
#branch bubbles
max_revenue = branch_revenue.max()

# %%
for branch, (lat, lon) in branch_coords.items():
    rev   = branch_revenue.get(branch, 0)
    txns  = branch_txns.get(branch, 0)
    radius = (rev / max_revenue) * 40 + 10 # Scale bubble size by revenue

    # Simple popup text
    popup_text = f"""
    Branch: {branch}
    Revenue: LKR {rev:,.0f}
    Transactions: {txns:,}
    """

    folium.CircleMarker(
        location=[lat, lon],
        radius=radius,
        color="white",
        fill=True,
        fill_color="steelblue",
        fill_opacity=0.7,
        popup=folium.Popup(popup_text, max_width=200),
        tooltip=f"{branch}: LKR {rev/1e6:.1f}M"
    ).add_to(m)

# %%
# ── Add customer city markers ────────────────────────────────────
for _, row in city_stats.iterrows():
    city = row["Customer_City"]
    if city in city_coords:
        lat, lon = city_coords[city]

        folium.CircleMarker(
            location=[lat, lon],
            radius=8,
            color="white",
            fill=True,
            fill_color="tomato",
            fill_opacity=0.6,
            popup=folium.Popup(
                f"City: {city}\nTransactions: {row['Transactions']:,}",
                max_width=200),
            tooltip=f"{city}: {row['Transactions']:,} transactions"
        ).add_to(m)

# %%
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2453c75d00ebe840b0ffc37a3de3faaa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2453c75d00ebe840b0ffc37a3de3faaa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2453c75d00ebe840b0ffc37a3de3faaa = L.map(
#                 &quot;map_2453c75d00ebe840b0ffc37a3de3faaa&quot;,
#                 {
#                     center: [7.8731, 80.7718],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6724d46aba55be8f0664ea01a6adee7b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6724d46aba55be8f0664ea01a6adee7b.addTo(map_2453c75d00ebe840b0ffc37a3de3faaa);
#
#
#             var circle_marker_bcc40ff6fa152e3edd4ae5a81610c2a7 = L.circleMarker(
#                 [6.9355, 79.8507],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;white&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;steelblue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2453c75d00ebe840b0ffc37a3de3faaa);
#
#
#         var popup_327835309913e98d7f9b4b9dffa3d53d = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_f9402e108bf4202dac44d21fb4df7bec = $(`&lt;div id=&quot;html_f9402e108bf4202dac44d21fb4df7bec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     Branch: Colombo Fort     Revenue: LKR 38,041,984     Transactions: 7,247     &lt;/div&gt;`)[0];
#                 popup_327835309913e98d7f9b4b9dffa3d53d.setContent(html_f9402e108bf4202dac44d21fb4df7bec);
#
#
#
#         circle_marker_bcc40ff6fa152e3edd4ae5a81610c2a7.bindPopup(popup_327835309913e98d7f9b4b9dffa3d53d)
#         ;
#
#
#
#
#             circle_marker_bcc40ff6fa152e3edd4ae5a81610c2a7.bindTooltip(
#                 `&lt;div&gt;
#                      Colombo Fort: LKR 38.0M
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_56036017c583c860450d17b1741fc38e = L.circleMarker(
#                 [7.2081, 79.8358],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;white&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;steelblue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 48.949536714621566, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2453c75d00ebe840b0ffc37a3de3faaa);
#
#
#         var popup_1b6a828e1905ad6c723c039988832b98 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_b4f25d0a9a096d27c88ec299def810a9 = $(`&lt;div id=&quot;html_b4f25d0a9a096d27c88ec299def810a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     Branch: Negombo     Revenue: LKR 37,042,941     Transactions: 7,041     &lt;/div&gt;`)[0];
#                 popup_1b6a828e1905ad6c723c039988832b98.setContent(html_b4f25d0a9a096d27c88ec299def810a9);
#
#
#
#         circle_marker_56036017c583c860450d17b1741fc38e.bindPopup(popup_1b6a828e1905ad6c723c039988832b98)
#         ;
#
#
#
#
#             circle_marker_56036017c583c860450d17b1741fc38e.bindTooltip(
#                 `&lt;div&gt;
#                      Negombo: LKR 37.0M
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_2a3a3921345fd0bae0964339c15d5133 = L.circleMarker(
#                 [7.2906, 80.6337],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;white&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;steelblue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 47.8810429501231, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2453c75d00ebe840b0ffc37a3de3faaa);
#
#
#         var popup_f85d1f28618fc1cc13c

# %% [markdown]
# **Profit category scatter plot**

# %%
cat_stats = sales_cleaned.groupby("Medicine_Category").agg(
    Revenue=("Line_Total_LKR", "sum"),
    Transactions=("Transaction_ID", "count"),
    AvgDiscount=("Discount_Rate", "mean")
).reset_index()

#scale bubble by transaction count
sizes = (cat_stats["Transactions"] / cat_stats["Transactions"].max() * 2000 + 200)

# %%
fig, ax = plt.subplots(figsize=(12, 7))

ax.scatter(cat_stats["AvgDiscount"] * 100,
           cat_stats["Revenue"] / 1e6,
           s=sizes,
           alpha=0.7,
           edgecolors="white",
           linewidths=1.5)
#code for category on each label of bubble
for _, row in cat_stats.iterrows():
    ax.annotate(row["Medicine_Category"],
                xy=(row["AvgDiscount"] * 100, row["Revenue"] / 1e6),
                xytext=(0, 10),
                textcoords="offset points",
                ha="center", fontsize=8)

#reference lines for averages
avg_discount = cat_stats["AvgDiscount"].mean() * 100
avg_revenue  = cat_stats["Revenue"].mean() / 1e6

ax.axvline(avg_discount, color="red", linestyle="--",
           alpha=0.5, label=f"Avg Discount {avg_discount:.1f}%")
ax.axhline(avg_revenue, color="blue", linestyle="--",
           alpha=0.5, label=f"Avg Revenue ₨{avg_revenue:.1f}M")

#labels and formatting
ax.set_title("Category Profitability — Revenue vs Discount Rate",
             fontsize=13)
ax.set_xlabel("Average Discount Rate (%)")
ax.set_ylabel("Total Revenue (Million LKR)")
ax.legend(fontsize=9)
ax.grid(axis="both", linestyle="--", alpha=0.4)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Radar Chart**

# %%
branch_kpi = sales_cleaned.groupby("Branch_Short").agg(
    Revenue=("Line_Total_LKR", "sum"),
    Transactions=("Transaction_ID", "count"),
    AvgTicket=("Line_Total_LKR", "mean"),
    AvgDiscount=("Discount_Rate", "mean"),
    PrescRatio=("Prescription_Required", lambda x: (x == "Yes").mean()),
    UniqueCategories=("Medicine_Category", "nunique"),
).reset_index()

kpis = ["Revenue", "Transactions", "AvgTicket","PrescRatio", "UniqueCategories"]

for col in kpis:
    mn, mx = branch_kpi[col].min(), branch_kpi[col].max()
    branch_kpi[f"N_{col}"] = (branch_kpi[col] - mn) / (mx - mn) #normalisation fo KPI between 0 and 1

    mn, mx = branch_kpi["AvgDiscount"].min(), branch_kpi["AvgDiscount"].max()
branch_kpi["N_MarginScore"] = 1 - (branch_kpi["AvgDiscount"] - mn) / (mx - mn)
# Invert discount — lower discount = higher margin score

# %%
radar_cols   = ["N_Revenue", "N_Transactions", "N_AvgTicket","N_PrescRatio", "N_UniqueCategories", "N_MarginScore"]
radar_labels = ["Revenue", "Transactions", "Avg Ticket","Rx Ratio", "Cat. Mix", "Margin Score"]

# %%
angles = np.linspace(0, 2 * np.pi, len(radar_labels),endpoint=False).tolist()
angles += angles[:1]

colors = ["steelblue", "tomato", "goldenrod", "seagreen","mediumpurple", "darkorange", "teal"]

# %%
fig, axes = plt.subplots(2, 4, figsize=(18, 9),subplot_kw=dict(polar=True))
axes = axes.flatten()

for idx, (_, row) in enumerate(branch_kpi.iterrows()):
    ax    = axes[idx]
    color = colors[idx]

    values   = [row[k] for k in radar_cols]
    values  += values[:1]

    # Background rings
    for r in [0.25, 0.5, 0.75, 1.0]:
        ax.plot(angles, [r] * (len(angles)),color="grey", linewidth=0.5,linestyle="--", alpha=0.5)

    # Plot radar shape
    ax.plot(angles, values, color=color, linewidth=2)
    ax.fill(angles, values, color=color, alpha=0.2)

    # Axis labels
    ax.set_thetagrids(np.degrees(angles[:-1]),
                      radar_labels, fontsize=8)
    ax.set_ylim(0, 1)
    ax.set_yticks([])
    ax.set_title(row["Branch_Short"], fontsize=10,
                 fontweight="bold", color=color, pad=10)

    # Revenue label below each subplot
    ax.text(0.5, -0.1, f"₨{row['Revenue']/1e6:.1f}M",
            transform=ax.transAxes, ha="center",
            fontsize=9, color=color)

# Hide last empty subplot
axes[-1].set_visible(False)

plt.suptitle("Branch Performance Radar — 6 KPI Comparison",
             fontsize=14, y=1.01)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Violin Plot**

# %%
#top 5 categories by revenue
top5 = (sales_cleaned.groupby("Medicine_Category")["Line_Total_LKR"].sum().nlargest(5).index.tolist())

# %%
sales_cleaned5 = sales_cleaned[sales_cleaned["Medicine_Category"].isin(top5)] # i only need to show top 5 only

# %%
colors = ["steelblue", "tomato", "goldenrod","seagreen", "mediumpurple"]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6),gridspec_kw={"width_ratios": [2, 1]})

#left panel
age_data = [sales_cleaned[sales_cleaned["Medicine_Category"] == cat]["Customer_Age"].values for cat in top5]
parts = ax1.violinplot(age_data,positions=range(len(top5)),widths=0.7,showmedians=True,showextrema=False)
#setting color for each violin
for i, (pc, color) in enumerate(zip(parts["bodies"], colors)):
    pc.set_facecolor(color)
    pc.set_alpha(0.55)
    pc.set_edgecolor("white")

parts["cmedians"].set_color("black")
parts["cmedians"].set_linewidth(2)

# Add IQR box and mean label on each violin
for i, (cat, color) in enumerate(zip(top5, colors)):
    ages = df5[df5["Medicine_Category"] == cat]["Customer_Age"]
    q1, med, q3 = ages.quantile([0.25, 0.5, 0.75])

    # IQR box
    ax1.plot([i, i], [q1, q3], color="black",
             linewidth=3, solid_capstyle="round")
    ax1.scatter([i], [med], color="white", s=40,
                zorder=5, edgecolors="black", linewidths=1.5)

    # Mean label above violin
    ax1.text(i, ages.max() + 1.5,
             f"μ={ages.mean():.0f}y\nn={len(ages):,}",
             ha="center", fontsize=8, color="grey")

ax1.set_xticks(range(len(top5)))
ax1.set_xticklabels(top5, rotation=15, ha="right", fontsize=9)
ax1.set_ylabel("Customer Age")
ax1.set_title("Age Distribution — Top 5 Categories", fontsize=11)
ax1.grid(axis="y", linestyle="--", alpha=0.4)

# %%
age_data = [sales_cleaned5[sales_cleaned5["Medicine_Category"] == cat]["Customer_Age"].values
            for cat in top5] #age value per category

# %%
fig, ax = plt.subplots(figsize=(10, 5))

ax.violinplot(age_data, positions=range(len(top5)))

ax.set_xticks(range(len(top5)))
ax.set_xticklabels(top5, rotation=15, ha="right")
ax.set_title("Customer Age Distribution by Top 5 Categories")
ax.set_xlabel("Medicine Category")
ax.set_ylabel("Customer Age")
plt.tight_layout()
plt.show()
